# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('until-totaltime.csv')

# %%
df
# Out:
#       third_ac   arrival from_station_code  \
# 0            0  12:15:00               JAT
# 1            0  08:35:00               UHP
# 2            0  17:50:00               JAT
# 3            0  19:50:00               UHP
# 4            1  12:30:00              BDTS
# ...        ...       ...               ...
# 4392         0  12:25:00              KDJR
# 4393         0  03:10:00              KOTA
# 4394         0  15:20:00               ASN
# 4395         0  20:45:00                VG
# 4396         0  08:10:00               CWA
#
#                                           name  zone  chair_car  first_class  \
# 0                  Jammu Tawi Udhampur Special    NR          0            0
# 1                       UDHAMPUR JAMMUTAWI DMU    NR          0            0
# 2                             JAT UDAHMPUR DMU    NR          0            0
# 3                       UDHAMPUR JAMMUTAWI DMU    NR          0            0
# ...

# %%
df.head()
# Out:
#    third_ac   arrival from_station_code                               name  \
# 0         0  12:15:00               JAT        Jammu Tawi Udhampur Special
# 1         0  08:35:00               UHP             UDHAMPUR JAMMUTAWI DMU
# 2         0  17:50:00               JAT                   JAT UDAHMPUR DMU
# 3         0  19:50:00               UHP             UDHAMPUR JAMMUTAWI DMU
# 4         1  12:30:00              BDTS  Mumbai BandraT-Bikaner SF Special
#
#   zone  chair_car  first_class  sleeper       from_station_name number  \
# 0   NR          0            0        0              JAMMU TAWI  04601
# 1   NR          0            0        0                UDHAMPUR  04602
# 2   NR          0            0        0              JAMMU TAWI  04603
# 3   NR          0            0        0                UDHAMPUR  04604
# 4  NWR          0            0        1  MUMBAI BANDRA TERMINUS  04728
#
#   departure return_train to_station_code  second_ac to_station_name  type  \
# ...

# %%
starting_station=df["from_station_name"].to_numpy(dtype=None,copy=False)

# %%
destination=df["to_station_name"].to_numpy(dtype=None,copy=False)

# %%
starting_station_names, count1 = np.unique(starting_station, return_counts=True)
destination_names, count2 = np.unique(starting_station, return_counts=True)

# %%
data = {'S.station':starting_station_names,
        'Frequency':count1}

# %%
starting_frame=pd.DataFrame(data)

# %%
starting_frame=starting_frame.sort_values(by='Frequency',ascending=False)
starting_frame=starting_frame.head(20)

# %%
starting_frame
# Out:
#                S.station  Frequency
# 253            HOWRAH JN        110
# 456            NEW DELHI         77
# 469            OLD DELHI         65
# 137      CHENNAI CENTRAL         63
# 55     BANGALORE CITY JN         56
# 5           AHMEDABAD JN         55
# 414           MUMBAI CST         49
# 366  LOKMANYA TILAK TERM         48
# 170   DELHI H NIZAMUDDIN         45
# 492              PUNE JN         42
# 485             PATNA JN         40
# 557      SECUNDERABAD JN         40
# 493                 PURI         39
# 20           AMRITSAR JN         39
# 638          VARANASI JN         37
# 657        YESVANTPUR JN         37
# 226         GORAKHPUR JN         37
# 270               JAIPUR         36
# 232             GUWAHATI         36
# 276           JAMMU TAWI         34

# %%
data1 = {'Destination':destination_names,
        'Frequency':count2}

# %%
destination_frame=pd.DataFrame(data1)

# %%
destination_frame=destination_frame.sort_values(by='Frequency',ascending=False)
destination_frame=destination_frame.head(20)

# %%
destination_frame
# Out:
#              Destination  Frequency
# 253            HOWRAH JN        110
# 456            NEW DELHI         77
# 469            OLD DELHI         65
# 137      CHENNAI CENTRAL         63
# 55     BANGALORE CITY JN         56
# 5           AHMEDABAD JN         55
# 414           MUMBAI CST         49
# 366  LOKMANYA TILAK TERM         48
# 170   DELHI H NIZAMUDDIN         45
# 492              PUNE JN         42
# 485             PATNA JN         40
# 557      SECUNDERABAD JN         40
# 493                 PURI         39
# 20           AMRITSAR JN         39
# 638          VARANASI JN         37
# 657        YESVANTPUR JN         37
# 226         GORAKHPUR JN         37
# 270               JAIPUR         36
# 232             GUWAHATI         36
# 276           JAMMU TAWI         34

# %%
#OBSERVATION : TO AND FRO SAME NUMBER OF TRAINS FOR A PARTICULAR STATION (except 1 or 2 deviation which is not visible in top 20)

# %%
plt.rcdefaults()
fig, ax = plt.subplots()
y_pos = np.arange(len(destination_frame['Destination']))

ax.barh(y_pos,destination_frame['Frequency'], align='center')
ax.set_yticks(y_pos)
ax.set_yticklabels(destination_frame['Destination'])
ax.invert_yaxis()  
ax.set_xlabel('Frequency')
ax.set_title('Top 20 busiest stations')

plt.show()
